# %%
def cuantificador_universal(Dominio, P):
    for x in Dominio:
        if not P(x):
            return False
    return True

# %%
def cuantificador_existencial(Dominio, P):
    for x in Dominio:
        if P(x):
            return True
    return False

# %%
A = [1, -2, 3, -4]
B = [1, 2, 3, 4]

# %%
Px = lambda x: x > 0
Qx = lambda x: x < 0

# %%
resultadoA_Univ = cuantificador_universal(A, Px)
print(resultadoA_Univ)
# Out:
# False

# %%
resultadoB_Univ = cuantificador_universal(B, Px)
print(resultadoB_Univ)
# Out:
# True

# %%
resultadoA_Ex = cuantificador_existencial(A, Qx)
print(resultadoA_Ex)
# Out:
# True

# %%
resultadoB_Ex = cuantificador_existencial(B, Qx)
print(resultadoB_Ex)
# Out:
# False
